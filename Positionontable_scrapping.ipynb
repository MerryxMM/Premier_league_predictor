# %%
# 760 means we have the correct data since each team plays 38 matches. 19 home and 19 away.
# we multiply 38*20/2 and we get all the matches that a season has (380) however we have the data of each matchweek for each team
# hence we dont divide it by 2 and we get 740 which is also the number of rows that we've got

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# Define base URL and seasons
base_url = 'https://www.worldfootball.net/schedule/eng-premier-league-'
seasons = [f'{year}-{year+1}' for year in range(2018, 2024)]
matchweeks = range(1, 39)

# Initialize an empty list to store the data
data = []

# Function to clean up team names
def clean_team_name(name):
    return name.split("\n")[0].strip()

# Loop through each season and matchweek
for season in seasons:
    for week in matchweeks:
        url = f'{base_url}{season}-spieltag/{week}/'
        response = requests.get(url)
        soup = BeautifulSoup(response.text, "lxml")

        # Find all tables
        tables = soup.find_all("table", class_="standard_tabelle")

        # Loop through tables to find the one with the correct headers
        target_table = None
        for table in tables:
            headers = [header.text.strip() for header in table.find_all('th')]
            if headers == ["#", "Team", "M.", "W", "D", "L", "goals", "Dif.", "Pt."]:
                target_table = table
                break

        if target_table:
            # Loop through each row in the found table
            for row in target_table.find_all('tr')[1:]:  # Skip the header row
                # Extract data from each cell in the row
                cells = row.find_all('td')
                if cells:  # Check if the row is not empty
                    position = cells[0].text.strip()
                    team = clean_team_name(cells[2].text.strip())
                    matches = cells[3].text.strip()
                    wins = cells[4].text.strip()
                    draws = cells[5].text.strip()
                    losses = cells[6].text.strip()
                    goals = cells[7].text.strip()
                    difference = cells[8].text.strip()
                    points = cells[9].text.strip()
                    # Append the row data along with matchweek and season
                    data.append({
                        'Position': position,
                        'Team': team,
                        'Matches': matches,
                        'Wins': wins,
                        'Draws': draws,
                        'Losses': losses,
                        'Goals': goals,
                        'Difference': difference,
                        'Points': points,
                        'Matchweek': week,
                        'Season': season
                    })
            print(f"Data collected for {season} matchweek {week}")
        else:
            print(f"No target table found for {season} matchweek {week}")

        # Delay the next request
        time.sleep(1)  # Wait for 2 seconds

# Convert the data list to a DataFrame
df = pd.DataFrame(data)

# Print the DataFrame
df
# Out:
# Data collected for 2018-2019 matchweek 1
# Data collected for 2018-2019 matchweek 2
# Data collected for 2018-2019 matchweek 3
# Data collected for 2018-2019 matchweek 4
# Data collected for 2018-2019 matchweek 5
# Data collected for 2018-2019 matchweek 6
# Data collected for 2018-2019 matchweek 7
# Data collected for 2018-2019 matchweek 8
# Data collected for 2018-2019 matchweek 9
# Data collected for 2018-2019 matchweek 10
# Data collected for 2018-2019 matchweek 11
# Data collected for 2018-2019 matchweek 12
# Data collected for 2018-2019 matchweek 13
# Data collected for 2018-2019 matchweek 14
# Data collected for 2018-2019 matchweek 15
# Data collected for 2018-2019 matchweek 16
# Data collected for 2018-2019 matchweek 17
# Data collected for 2018-2019 matchweek 18
# Data collected for 2018-2019 matchweek 19
# Data collected for 2018-2019 matchweek 20
# Data collected for 2018-2019 matchweek 21
# Data collected for 2018-2019 matchweek 22
# Data collected for 2018-2019 matchweek 23
# Data collected for 2022-2023 matchweek 18
# Data collected for 2022-2023 matchweek 19
# Data collected for 2022-2023 matchweek 20
# Data collected for 2022-2023 matchweek 21
# Data collected for 2022-2023 matchweek 22
# Data collected for 2022-2023 matchweek 23
# Data collected for 2022-2023 matchweek 24
# Data collected for 2022-2023 matchweek 25
# Data collected for 2022-2023 matchweek 26
# Data collected for 2022-2023 matchweek 27
# Data collected for 2022-2023 matchweek 28
# Data collected for 2022-2023 matchweek 29
# Data collected for 2022-2023 matchweek 30
# Data collected for 2022-2023 matchweek 31
# Data collected for 2022-2023 matchweek 32
# Data collected for 2022-2023 matchweek 33
# Data collected for 2022-2023 matchweek 34
# Data collected for 2022-2023 matchweek 35
# Data collected for 2022-2023 matchweek 36
# Data collected for 2022-2023 matchweek 37
# Data collected for 2022-2023 matchweek 38
# Data collected for 2023-2024 matchweek 1
# Data collected for 2023-2024 matchweek 2
# Data collected for 2023-2024 matchweek 3
# Data collected for 2023-2024 matchweek 4
# Data collected for 2023-2024 matchweek 5
# Data collected for 2023-2024 matchweek 6
# Data collected for 2023-2024 matchweek 7
# Data collected for 2023-2024 matchweek 8
# Data collected for 2023-2024 matchweek 9
# Data collected for 2023-2024 matchweek 10
# Data collected for 2023-2024 matchweek 11
# Data collected for 2023-2024 matchweek 12
# Data collected for 2023-2024 matchweek 13
# Data collected for 2023-2024 matchweek 14
# Data collected for 2023-2024 matchweek 15
# Data collected for 2023-2024 matchweek 16
# Data collected for 2023-2024 matchweek 17
# Data collected for 2023-2024 matchweek 18
# Data collected for 2023-2024 matchweek 19
# Data collected for 2023-2024 matchweek 20
# Data collected for 2023-2024 matchweek 21
# Data collected for 2023-2024 matchweek 22
# Data collected for 2023-2024 matchweek 23
# Data collected for 2023-2024 matchweek 24
# Data collected for 2023-2024 matchweek 25
# Data collected for 2023-2024 matchweek 26
# Data collected for 2023-2024 matchweek 27
# Data collected for 2023-2024 matchweek 28
# Data collected for 2023-2024 matchweek 29
# Data collected for 2023-2024 matchweek 30
# Data collected for 2023-2024 matchweek 31
# Data collected for 2023-2024 matchweek 32
# Data collected for 2023-2024 matchweek 33
# Data collected for 2023-2024 matchweek 34
# Data collected for 2023-2024 matchweek 35
# Data collected for 2023-2024 matchweek 36
# Data collected for 2023-2024 matchweek 37
# Data collected for 2023-2024 matchweek 38
#      Position               Team Matches Wins Draws Losses   Goals Difference  \
# 0           1       Liverpool FC       1    1     0      0     4:0          4
# 1           2         Chelsea FC       1    1     0      0     3:0          3
# 2           3    AFC Bournemouth       1    1     0      0     2:0          2
# 3                 Crystal Palace       1    1     0      0     2:0          2
# 4                Manchester City       1    1     0      0     2:0          2
# ...       ...                ...     ...  ...   ...    ...     ...        ...
# 4555       16       Brentford FC      38   10     9     19   56:65         -9
# 4556       17  Nottingham Forest      38    9     9     20   49:67        -18
# 4557       18         Luton Town      38    6     8     24   52:85        -33
# 4558       19         Burnley FC      38    5     9     24   41:78        -37
# 4559       20   Sheffield United      38    3     7     28  35:104        -69
#
#      Points  Matchweek     Season
# 0         3          1  2018-2019
# 1         3          1  2018-2019
# 2         3          1  2018-2019
# 3         3          1  2018-2019
# 4         3          1  2018-2019
# ...     ...        ...        ...
# 4555     39         38  2023-2024
# 4556     32         38  2023-2024
# 4557     26         38  2023-2024
# 4558     24         38  2023-2024
# 4559     16         38  2023-2024
#
# [4560 rows x 11 columns]

# %%
df
# Out:
#      Position               Team Matches Wins Draws Losses   Goals Difference  \
# 0           1       Liverpool FC       1    1     0      0     4:0          4
# 1           2         Chelsea FC       1    1     0      0     3:0          3
# 2           3    AFC Bournemouth       1    1     0      0     2:0          2
# 3                 Crystal Palace       1    1     0      0     2:0          2
# 4                Manchester City       1    1     0      0     2:0          2
# ...       ...                ...     ...  ...   ...    ...     ...        ...
# 4555       16       Brentford FC      38   10     9     19   56:65         -9
# 4556       17  Nottingham Forest      38    9     9     20   49:67        -18
# 4557       18         Luton Town      38    6     8     24   52:85        -33
# 4558       19         Burnley FC      38    5     9     24   41:78        -37
# 4559       20   Sheffield United      38    3     7     28  35:104        -69
#
#      Points  Matchweek     Season
# 0         3          1  2018-2019
# 1         3          1  2018-2019
# 2         3          1  2018-2019
# 3         3          1  2018-2019
# 4         3          1  2018-2019
# ...     ...        ...        ...
# 4555     39         38  2023-2024
# 4556     32         38  2023-2024
# 4557     26         38  2023-2024
# 4558     24         38  2023-2024
# 4559     16         38  2023-2024
#
# [4560 rows x 11 columns]

# %%
df.head(40)
# Out:
#    Position                     Team Matches Wins Draws Losses Goals  \
# 0         1             Liverpool FC       1    1     0      0   4:0
# 1         2               Chelsea FC       1    1     0      0   3:0
# 2         3          AFC Bournemouth       1    1     0      0   2:0
# 3                     Crystal Palace       1    1     0      0   2:0
# 4                    Manchester City       1    1     0      0   2:0
# 5                         Watford FC       1    1     0      0   2:0
# 6         7        Manchester United       1    1     0      0   2:1
# 7                  Tottenham Hotspur       1    1     0      0   2:1
# 8         9               Everton FC       1    0     1      0   2:2
# 9            Wolverhampton Wanderers       1    0     1      0   2:2
# 10       11               Burnley FC       1    0     1      0   0:0
# 11                    Southampton FC       1    0     1      0   0:0
# 12       13           Leicester City       1    0     0      1   1:2
# 13                  Newcastle United       1    0     0      1   1:2
# 14       15               Arsenal FC       1    0     0      1   0:2
# 15            Brighton & Hove Albion       1    0     0      1   0:2
# 16                      Cardiff City       1    0     0      1   0:2
# 17                         Fulham FC       1    0     0      1   0:2
# 18       19        Huddersfield Town       1    0     0      1   0:3
# 19       20          West Ham United       1    0     0      1   0:4
# 20        1          Manchester City       2    2     0      0   8:1
# 21        2             Liverpool FC       2    2     0      0   6:0
# 22        3               Chelsea FC       2    2     0      0   6:2
# 23        4               Watford FC       2    2     0      0   5:1
# 24        5        Tottenham Hotspur       2    2     0      0   5:2
# 25        6          AFC Bournemouth       2    2     0      0   4:1
# 26        7               Everton FC       2    1     1      0   4:3
# 27        8           Leicester City       2    1     0      1   3:2
# 28        9        Manchester United       2    1     0      1   4:4
# 29       10           Crystal Palace       2    1     0      1   2:2
# 30       11   Brighton & Hove Albion       2    1     0      1   3:4
# 31       12         Newcastle United       2    0     1      1   1:2
# 32                    Southampton FC       2    0     1      1   1:2
# 33       14  Wolverhampton Wanderers       2    0     1      1   2:4
# 34       15               Burnley FC       2    0     1      1   1:3
# 35       16             Cardiff City       2    0     1      1   0:2
# 36       17               Arsenal FC       2    0     0      2   2:5
# 37       18                Fulham FC       2    0     0      2   1:5
# 38       19          West Ham United       2    0     0      2   1:6
# 39       20        Huddersfield Town       2    0     0      2   1:9
#
#    Difference Points  Matchweek     Season
# 0           4      3          1  2018-2019
# 1           3      3          1  2018-2019
# 2           2      3          1  2018-2019
# 3           2      3          1  2018-2019
# 4           2      3          1  2018-2019
# 5           2      3          1  2018-2019
# 6           1      3          1  2018-2019
# 7           1      3          1  2018-2019
# 8           0      1          1  2018-2019
# 9           0      1          1  2018-2019
# 10          0      1          1  2018-2019
# 11          0      1          1  2018-2019
# 12         -1      0          1  2018-2019
# 13         -1      0          1  2018-2019
# 14         -2      0          1  2018-2019
# 15         -2      0          1  2018-2019
# 16         -2      0          1  2018-2019
# 17         -2      0          1  2018-2019
# 18         -3      0          1  2018-2019
# 19         -4      0          1  2018-2019
# 20          7      6          2  2018-2019
# 21          6      6          2  2018-2019
# 22          4      6          2  2018-2019
# 23          4      6          2  2018-2019
# 24          3      6          2  2018-2019
# 25          3      6          2  2018-2019
# 26          1      4          2  2018-2019
# 27          1      3          2  2018-2019
# 28          0      3          2  2018-2019
# 29          0      3          2  2018-2019
# 30         -1      3          2  2018-2019
# 31         -1      1          2  2018-2019
# 32         -1      1          2  2018-2019
# 33         -2      1          2  2018-2019
# 34         -2      1          2  2018-2019
# 35         -2      1          2  2018-2019
# 36         -3      0          2  2018-2019
# 37         -4      0          2  2018-2019
# 38         -5      0          2  2018-2019
# 39         -8      0          2  2018-2019

# %%
df.isnull().sum()

# %% [markdown]
# df["Team"].value_counts()

# %%
team_counts = df["Team"].value_counts().sort_index()
team_counts

# %%
# formating some columns to allign the format with the other dataframes, also dropping unuseful columns
df.rename(columns={'Team': 'HomeTeam'}, inplace=True)
df.rename(columns={'Difference': 'Goal_Difference'}, inplace=True)
df.drop(columns=['Goals'], inplace=True)

# %%
# changing the seasons to just one to have them as numerical values
df['Season'] = df['Season'].str.split('-').str[0].astype(int)

# %%
df.head(40)

# %%
df.isnull().sum()

# %%
df.columns

# %%
# Save the DataFrame to a CSV file
df.to_csv('premier_league_data.csv', index=False)

print("Data scraping completed and saved to premier_league_data.csv")

# %%
df["Season"].value_counts()

# %%
df["Position"].isnull().sum()
